# %%
# Import modules
from pymongo import MongoClient
import pandas as pd
import json as js
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import fun

# %%
client = MongoClient("mongodb://localhost/companies")
db = client.get_database()

# %%
df = pd.DataFrame(list(db["companies"].find({'founded_year': {'$gte':2003}})))
df.shape
# Out:
# (9297, 42)

# %%
# DataFrame with companies founded before 2003
df_oldestcomp = pd.DataFrame(list(db['companies'].find({'founded_year': {'$lt': 2003}}, {"name":1,"offices":1,"category_code":1})))
df_oldestcomp.shape
# Out:
# (3839, 4)

# %%
# Total companies with declared founded year = 13.136.
# Companies with founded year null = 5665

# %%
#To filter for tech startups that raised more than $1M, first know which types of startups are in the database

startups_type = list(db['companies'].distinct('category_code'))

# %%
# Data Frame with Tech Statups founded after 2002 that raised $1M on a funding round. 6977
df = pd.DataFrame(list(db['companies'].find({'$and': [{'founded_year': {'$gte':2003}}, {'category_code': {'$in': ['advertising', 'analytics', 'consulting', 'design', 'ecommerce', 'games_video', 'hardware', 'mobile', 'nanotech', 'network_hosting', 'software', 'web']}}, {'funding_rounds.raised_amount': {'$gte': 1000000}}]}, {"name":1,"offices":1,"category_code":1})))
df.shape
# Out:
# (1468, 4)

# %%
# Create a DataFrame with Starbucks location 
df_st = pd.read_csv('input/starbucks.csv', engine='python')
df_st = df_st[['Brand', 'Name', 'City', 'Country', 'Latitude', 'Longitude']]
df_st = df_st.dropna(subset= ['Latitude', 'Longitude'])

# %%
#Create a DataFrame with USA airports from a csv and filter it
df_airports = pd.read_csv("input/airports.csv", engine = 'python')
df_airports = df_airports.dropna(subset=['wikipedia_link'])
df_airports = df_airports[(df_airports['type'] == 'large_airport')]
df_airports = df_airports[['name', 'latitude_deg', 'longitude_deg']]

# %%
# Explode offices to have each office (dictionary, part of a list) on a row
df = df.explode('offices')

# Expand offices info into different columns
dfOffices = df[["offices"]].apply(lambda r: r.offices, result_type="expand", axis=1)

#Concanete both DataFrames
cleanData = pd.concat([df,dfOffices], axis=1)

# %%
#Same process for DataFrame of companies founded before 2003
df_oldestcomp = df_oldestcomp.explode('offices')
df_oldestcompOffices = df_oldestcomp[['offices']].apply(lambda r: r.offices, result_type='expand', axis=1)
oldestOffices = pd.concat([df_oldestcomp,df_oldestcompOffices], axis=1)

# %%
# Cleaning offices DataFrame dropping unnecessary columns and null info for latitude and longitude
cleanData = cleanData.drop(columns= ['_id', 'offices'])
cleanData = cleanData.dropna(subset= ['latitude', 'longitude'])

# %%
# Cleaning oldest offices DataFrame dropping unnecessary columns and null info for latitude and longitude
oldestOffices = oldestOffices.drop(columns= ['_id', 'offices'])
oldestOffices = oldestOffices.dropna(subset= ['latitude', 'longitude'])

# %%
#Create GEOJSON
cleanData["location"] = cleanData[["latitude","longitude"]].apply(lambda x:asGeoJSON(x.latitude,x.longitude), axis=1)

oldestOffices["location"] = oldestOffices[["latitude","longitude"]].apply(lambda x:asGeoJSON(x.latitude,x.longitude), axis=1)

df_st['location'] = df_st[['Latitude', 'Longitude']].apply(lambda x:asGeoJSON(x.Latitude,x.Longitude), axis=1)

df_airports['location'] = df_airports[['latitude_deg', 'longitude_deg']].apply(lambda x:asGeoJSON(x.latitude_deg,x.longitude_deg), axis=1)

# %%
# Select 3 cities from the original DataFrame based on the number of value_counts of startups in the original DataFrame 
cleanData['city'].value_counts().head(3)

# Cities to compare: San Francisco, New York, Mountain View
# Filter both DataFrames where cities are previous ones.

cleanData = cleanData[(cleanData['city'] == 'San Francisco') | (cleanData['city'] == 'New York') | (cleanData['city'] == 'Mountain View')]

df_st = df_st[(df_st['City'] == 'San Francisco') | (df_st['City'] == 'New York') | (df_st['City'] == 'Mountain View')]

oldestOffices = oldestOffices[(oldestOffices['city'] == 'San Francisco') | (oldestOffices['city'] == 'New York') | (oldestOffices['city'] == 'Mountain View')]

# %%
# Exporting data for MongoDB. 
cleanData.to_json("output/cleanOffices.json", orient="records")
oldestOffices.to_json("output/oldestOffices.json", orient="records")
df_st.to_json("output/starbucks.json", orient="records")
df_airports.to_json("output/airports.json", orient="records")

# %%
#How many oldcompanies, starbucks and airports are nearby the offices filtered.
cleanData['oldcompanies'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'oldestOffices', 2000))
cleanData['starbucks'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'starbucks', 500))
cleanData['airports'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'airports', 10000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-72cfbe3dea24> in <module>
#       1 #How many oldcompanies, starbucks and airports are nearby the offices filtered.
# ----> 2 cleanData['oldcompanies'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'oldestOffices', 2000))
#       3 cleanData['starbucks'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'starbucks', 500))
#       4 cleanData['airports'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'airports', 10000))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3847             else:
#    3848                 values = self.astype(object).values
# -> 3849                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3850
#    3851         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-138-72cfbe3dea24> in <lambda>(x)
#       1 #How many oldcompanies, starbucks and airports are nearby the offices filtered.
# ----> 2 cleanData['oldcompanies'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'oldestOffices', 2000))
#       3 cleanData['starbucks'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'starbucks', 500))
#       4 cleanData['airports'] = cleanData['location'].apply(lambda x: FunFunctions.officesComp(x, 'airports', 10000))
#
# ~/geo_project/FunFunctions.py in officesComp(coord, bd, meters)
#      11         "coordinates":[lng,lat]
#      12     }
# ---> 13
#      14 def officesComp(coord, bd, meters):
#      15     '''Function to know distance from office to old company, starbucks, airport, bar, etc...'''
#
# NameError: name 'db' is not defined

# %%
cleanData.head()
# Out:
#                name category_code      description              address1  \
# 0          Wetpaint           web                   270 Lafayette Street
# 3             Joost   games_video                       100 5th Ave Fl 6
# 5           AddThis   advertising  New York Office          568 Broadway
# 9              Kyte   games_video             None       442 Post Street
# 11  Jingle Networks        mobile                     475 Park Ave South
#
#                   address2    zip_code           city state_code country_code  \
# 0                Suite 505       10012       New York         NY          USA
# 3                           10011-6903       New York         NY          USA
# 5   11th Floor, Suite 1105       10012       New York         NY          USA
# 9               10th Floor       94102  San Francisco         CA          USA
# 11              10th Floor       10016       New York         NY          USA
#
#      latitude   longitude                                           location  \
# 0   40.723731  -73.996431  {'type': 'Point', 'coordinates': [-73.9964312,...
# 3   40.746497  -74.009447  {'type': 'Point', 'coordinates': [-74.0094471,...
# 5   40.724604  -73.996876  {'type': 'Point', 'coordinates': [-73.996876, ...
# 9   37.788482 -122.409173  {'type': 'Point', 'coordinates': [-122.409173,...
# 11  37.480999 -122.173887  {'type': 'Point', 'coordinates': [-122.173887,...
#
#     oldcompanies  starbucks  airports
# 0             38          4         0
# 3             34          0         0
# 5             36          4         0
# 9             96         10         0
# 11             0          0         0

# %%
# Assign a weight
airport = 0.8
starbuck = 0.6
oldcompanies = 0.9

cleanData['Ranking'] = cleanData['airports'].rank(method='max') * airport + cleanData['starbucks'].rank(method='max') * starbuck - cleanData['oldcompanies'].rank(method='max') * oldcompanies

# %%
cleanData.head()
# Out:
#                name category_code      description              address1  \
# 0          Wetpaint           web                   270 Lafayette Street
# 3             Joost   games_video                       100 5th Ave Fl 6
# 5           AddThis   advertising  New York Office          568 Broadway
# 9              Kyte   games_video             None       442 Post Street
# 11  Jingle Networks        mobile                     475 Park Ave South
#
#                   address2    zip_code           city state_code country_code  \
# 0                Suite 505       10012       New York         NY          USA
# 3                           10011-6903       New York         NY          USA
# 5   11th Floor, Suite 1105       10012       New York         NY          USA
# 9               10th Floor       94102  San Francisco         CA          USA
# 11              10th Floor       10016       New York         NY          USA
#
#      latitude   longitude                                           location  \
# 0   40.723731  -73.996431  {'type': 'Point', 'coordinates': [-73.9964312,...
# 3   40.746497  -74.009447  {'type': 'Point', 'coordinates': [-74.0094471,...
# 5   40.724604  -73.996876  {'type': 'Point', 'coordinates': [-73.996876, ...
# 9   37.788482 -122.409173  {'type': 'Point', 'coordinates': [-122.409173,...
# 11  37.480999 -122.173887  {'type': 'Point', 'coordinates': [-122.173887,...
#
#     oldcompanies  starbucks  airports  Ranking  \
# 0             38          4         0    196.4
# 3             34          0         0    152.6
# 5             36          4         0    200.0
# 9             96         10         0     95.6
# 11             0          0         0    237.2
#
#                                          trainstation
# 0   {'error_message': 'The provided API key is inv...
# 3   {'error_message': 'The provided API key is inv...
# 5   {'error_message': 'The provided API key is inv...
# 9   {'error_message': 'The provided API key is inv...
# 11  {'error_message': 'The provided API key is inv...

# %%
cleanData.sort_values(by=['Ranking'], ascending=False).reset_index(drop=True).head()
# Out:
#                        name category_code      description  \
# 0                      RayV   games_video             None
# 1                   muzu tv           web  New York Office
# 2  The Receivables Exchange     ecommerce  New York Office
# 3                  Cellfish           web
# 4                    Vringo      software               HQ
#
#                          address1         address2    zip_code      city  \
# 0            150 West 77, Suite 4             None        None  New York
# 1                 345 Park Avenue       17th Floor  10154-0037  New York
# 2  437 Madison Avenue, 28th Floor                        10022  New York
# 3            215 Lexington Avenue                        10016  New York
# 4                780 Third Avenue  Fifteenth Floor       10017  New York
#
#   state_code country_code   latitude  longitude  \
# 0         NY          USA  40.781159 -73.978332
# 1         NY          USA  40.757716 -73.972321
# 2         NY          USA  40.757651 -73.975277
# 3         NY          USA  40.761855 -73.983754
# 4         NY          USA  40.755001 -73.971736
#
#                                             location  oldcompanies  starbucks  \
# 0  {'type': 'Point', 'coordinates': [-73.978332, ...             3          5
# 1  {'type': 'Point', 'coordinates': [-73.972321, ...            70         17
# 2  {'type': 'Point', 'coordinates': [-73.9752768,...            75         20
# 3  {'type': 'Point', 'coordinates': [-73.983754, ...            75         20
# 4  {'type': 'Point', 'coordinates': [-73.9717364,...            72         15
#
#    airports  Ranking                                       trainstation
# 0         1    318.5  {'error_message': 'The provided API key is inv...
# 1         1    290.6  {'error_message': 'The provided API key is inv...
# 2         1    283.7  {'error_message': 'The provided API key is inv...
# 3         1    283.7  {'error_message': 'The provided API key is inv...
# 4         1    280.7  {'error_message': 'The provided API key is inv...

# %%
closest_starbucks = nearestStarbucks(cleanData['latitude'][0], cleanData['longitude'][0])
closest_airports = nearestAirports(cleanData['latitude'][0], cleanData['longitude'][0])
closest_comp = nearestComp(cleanData['latitude'][0], cleanData['longitude'][0])

# %%
lat = cleanData['latitude'][0]
lon = cleanData['longitude'][0]
map_ = folium.Map(location=[lat, lon],tiles='cartodbpositron', zoom_start=15)
Marker([lat, lon], icon=folium.Icon(color='red')).add_to(map_)
for point in closest_starbucks:
    Marker(point, icon=folium.Icon(color='green')).add_to(map_)
for point in closest_airports:
    Marker(point, icon=folium.Icon(color='blue')).add_to(map_)
for point in closest_comp:
    Marker(point, icon=folium.Icon(color='black')).add_to(map_)
print(lat,lon)
map_

#No he conseguido pintar los aeropuertos. 
#He tenido que triplicar las funciones nearest porque cada en diccionario que devuelve, latitude y longitude recibe un nombre diferente.
# Out:
# 40.7237306 -73.9964312
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
